# %%
# %run mis_int.ipynb

# %%
def osc(y,t,wo2=1.):
    
    return array([y[1],-wo2*sin(y[0])+ 0.1*sin(t)]) # dandole un valor a g(t)

# %%
for i in range(3):   # generando un numero n de trayectorias que 
    y0,u0= pi*(2*rand()-1),0 #4*2*rand()-1 # si hacemos u= entonces obtendremos trayectorias cerradas.
    t,sol= R_Kutta_4(osc,[y0,u0],[0,200.])# 
    plot(sol[:,0],sol[:,1],)
zoom=pi
xlim([-zoom,zoom]), ylim([-zoom,zoom])
axes().set_aspect('equal'), grid(True)
show()

# %%
y0,u0= 1.2,0#4*2*rand()-1 # si hacemos u= entonces obtendremos trayectorias cerradas.
t,sol= R_Kutta_4(osc,[y0,u0],[0,2000.])# variamos el número de ciclos pero no rebasa el espacio fase donde se define
plot(sol[:,0],sol[:,1],)
y0,u0= 1.21,0#4*2*rand()-1 # si hacemos u= entonces obtendremos trayectorias cerradas.
t,sol= R_Kutta_4(osc,[y0,u0],[0,2000.])# variamos el número de ciclos pero no rebasa el espacio fase donde se define
plot(sol[:,0],sol[:,1],)
zoom=pi
xlim([-zoom,zoom]), ylim([-zoom,zoom])
axes().set_aspect('equal'), grid(True)
show()

# %% [markdown]
# Cambiamos el pinto de inicio pero siguen en la misma "banda" no se salen del espacio fase
